# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import numpy as np
import torch

from umap.umap_ import UMAP
from sklearn.manifold import TSNE
from sentence_transformers import SentenceTransformer
from sklearn.cluster import KMeans, DBSCAN, AffinityPropagation
from tqdm import tqdm

# %%
class VectorStore:
    def __init__(self, model, size):
        self.documents = []
        self.embeddings = np.empty(size)
        self.model = model  

    def add_to_store(self, document):
        self.documents.append(document)
        embedding = self.model.encode(document, convert_to_numpy=True, normalize_embeddings=True, show_progress_bar=False, batch_size=32)
        self.embeddings = np.vstack((self.embeddings, embedding))

# %%
def build_scatter_2d(data, projections, title):
    fig = px.scatter(projections,
                x=0, 
                y=1,
                color=data['labels'], 
                labels={'color': 'category'},
                template='plotly_dark',
                height=700,
                )

    fig.update_layout(
                title={'text': title,
                        'y':0.95,
                        'x':0.5},
                showlegend=True)

    fig.show()

# %%
df = pd.read_csv('./data/part_1_BIG_MODELfor_merge.csv')

# %%
df2 = pd.read_csv('./data/part_2_for_merge.csv')

# %%
df = df.join(df2)

# %%
df = df.dropna(subset=['product', 'location', 'description']).reset_index(drop=True)

# %%
df
# Out:
#                                               location  \
# 0                            Гуандун, Чжунцин, Каннинг
# 1    Немонгольский автономный район, УНИТА, правый ...
# 2    Синьцзян-Уйгурский автономный район и Тэгу, ок...
# 3                            Хубэй, Хуанган, округ Чун
# 4                                        Пекин, Тойота
# ..                                                 ...
# 380  Автономный район Гуанси-Маньчжур, муниципалите...
# 381                Гуанси-Шань; город Порт-оф-Си; порт
# 382  Цинго, округ Цинго, провинция Хэйлунцзян, Цзин...
# 383                                            Гуандун
# 384  Синьцзян-Уйгурский автономный округ, Баян-Монг...
#
#                                                product     tender_number  \
# 0                      оборудование для замены коробок  CGN-202305310008
# 1                    оборудование для оптических камер  CGN-202211140006
# 2                  1 млн. кВт оптико-волнового поля PC  CGN-202307050014
# 3                          гидроэнергетическая станция  CGN-202301310002
# 4                   сбор фотоэлектрических компонентов  CGN-202307040015
# ..                                                 ...               ...
# 380                     ветрогенераторное оборудование   CGN-20221220004
# 381  материалы для комбинированной модификации гене...  CGN-202301180008
# 382            оборудование для преобразования коробок  CGN-202305310011
# 383  Проектные блоки LOT88Ea & LOT88Ea для борьбы с...   CGN-20230103001
# 384  35-кислотных линий электропередачи в случае 1 ...  CGN-202307130012
#
#     tender_name                      tender_company  quantity  \
# 0           NaN       Новая энергетическая компания       NaN
# 1           NaN       Новая энергетическая компания       NaN
# 2           NaN  China Solar Energy Successing Ltd.       NaN
# 3           NaN                Чайна нью-Энтерпрайз       NaN
# 4           NaN                          Чайна Хинэ       NaN
# ..          ...                                 ...       ...
# 380         NaN                                 NaN       NaN
# 381         NaN                    Хинси энтерпрайз       NaN
# 382         NaN                               Киото       NaN
# 383         NaN                                 NaN       NaN
# 384         NaN                                 NaN       NaN
#
#                                            description  \
# 0    Проект <<Хиннин>>, расположенный в городе Цзян...
# 1    Закупка оборудования для фотоаппаратов УНИТА в...
# 2    Общий контрактный проект PC в 1 млн кВт-диапаз...
# 3    Проект &lt; &lt; Старый ветер в Синьцзян-Тауне...
# 4    С 2023 по 2024 гг. были собраны матрицы фотоэл...
# ..                                                 ...
# 380  На юго-западе юго-западного района Порт-Куньси...
# 381  атомная электростанция порта Гуанси находится ...
# 382  новая энергетическая ветряная площадка &lt; &l...
# 383  &lt; &lt; Ядерная энергетика Китая и Китая &gt...
# 384  Закупка 1 млн. ветровых линий электропередачи ...
#
#                                           requirements  \
# 0    Этот тендер будет состоять из первого сегмента...
# 1    Участники торгов предоставили три комплекта ка...
# 2    Упаковка 1: первый этап проекта генерального п...
# 3    Содержание и сфера охвата данного тендера вклю...
# 4    Данный тендерный проект разделен на семь пункт...
# ..                                                 ...
# 380  В рамках этого тендера были закуплены ветряное...
# 381  данный тендерный проект разделен на 1 пункт, к...
# 382  4-й пункт: «Геронцзян Юнг». Поставки включают ...
# 383  сейф для борьбы с пожарными клапанами ядерного...
# 384  Подробная информация о конкретных потребностях...
#
#                                                 stages  \
# 0    четыре сегмента: 1-й пункт: кузов; 2-й участок...
# 1                                                    2
# 2                                      четыре сегмента
# 3                                 347 календарных дней
# 4                                                    7
# ..                                                 ...
# 380  Вместимость проекта составляет 50 МВт, а общая...
# 381                                                  1
# 382                                                  4
# 383                                                NaN
# 384  Работы планируется начать 20 августа 2023 года...
#
#                                          delivery_time  start_date    end_date
# 0    Предварительный 15 августа 2023 года; срок око...  15.08.2023         NaN
# 1                                 до 10 июня 2023 года         NaN         NaN
# 2    Планируемый период работы составляет с 15 авгу...  15.08.2023  30.12.2023
# 3                                 347 календарных дней  28.02.2023  10.02.2024
# 4                                                  NaN        2023        2024
# ..                                                 ...         ...         ...
# 380                                         20.05.2023  20.05.2023  20.05.2023
# 381                                         15.07.2023  15.07.2023  31.12.2025
# 382                                         20.08.2023  20.08.2023         NaN
# 383                               1 сентября 2023 года         NaN         NaN
# 384                                                NaN  20.08.2023  30.11.2023
#
# [385 rows x 12 columns]

# %%
model_name = '../models/embaas_sentence-transformers-e5-large-v2/'

# %%
device = torch.device("mps")
device
# Out:
# device(type='mps')

# %%
model = SentenceTransformer(model_name, device=device)
model[1].pooling_mode_mean_tokens = False
model[1].pooling_mode_cls_token = True
model
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 512, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 1024, 'pooling_mode_cls_token': True, 'pooling_mode_mean_tokens': False, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
#   (2): Normalize()
# )

# %%
store_product = VectorStore(model, size=(0, model[1].word_embedding_dimension)) 
for i in tqdm(range(df.shape[0])):
    store_product.add_to_store(df['product'][i])
# Out:
# 100%|██████████| 385/385 [01:19<00:00,  4.86it/s]

# %%
store_product.embeddings.shape
# Out:
# (385, 1024)

# %%
umap_model = UMAP(n_neighbors=5, min_dist=0.3, metric='correlation', random_state=42, n_components=2)
projections = umap_model.fit_transform(store_product.embeddings)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/umap/umap_.py:1943: UserWarning:
#
# n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.

# %%
kmeans = KMeans(n_clusters=5)
kmeans.fit(projections)
labels = kmeans.labels_
data_labeled = np.column_stack((projections, labels))
temp_df = pd.DataFrame(data_labeled, columns=['X', 'Y', 'labels'])
temp_df['labels'] = temp_df['labels'].astype('str')
# Out:
# /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning

# %%
build_scatter_2d(temp_df, projections, 'Product: K-means / UMAP')

# %%
df['product_cluster'] = labels

# %% [markdown]
# location

# %%
store_location = VectorStore(model, size=(0, model[1].word_embedding_dimension)) 
for i in tqdm(range(df.shape[0])):
    store_location.add_to_store(df['location'][i])
# Out:
# 100%|██████████| 385/385 [00:16<00:00, 23.69it/s]

# %%
store_location.embeddings.shape
# Out:
# (385, 1024)

# %%
umap_model = UMAP(n_neighbors=5, min_dist=0.3, metric='correlation', random_state=42, n_components=2)
projections = umap_model.fit_transform(store_location.embeddings)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/umap/umap_.py:1943: UserWarning:
#
# n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#
# /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/umap/spectral.py:550: UserWarning:
#
# Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!

# %%
kmeans = KMeans(n_clusters=30)
kmeans.fit(projections)
labels = kmeans.labels_
data_labeled = np.column_stack((projections, labels))
temp_df = pd.DataFrame(data_labeled, columns=['X', 'Y', 'labels'])
temp_df['labels'] = temp_df['labels'].astype('str')
# Out:
# /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning

# %%
build_scatter_2d(temp_df, projections, 'Location: K-means / UMAP')

# %%
df['location_cluster'] = labels

# %%
store_descrition = VectorStore(model, size=(0, model[1].word_embedding_dimension)) 
for i in tqdm(range(df.shape[0])):
    store_descrition.add_to_store(df['description'][i])
# Out:
# 100%|██████████| 385/385 [00:16<00:00, 24.05it/s]

# %%
umap_model = UMAP(n_neighbors=5, min_dist=0.3, metric='correlation', random_state=42, n_components=2)
projections = umap_model.fit_transform(store_descrition.embeddings)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/umap/umap_.py:1943: UserWarning:
#
# n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(projections)
labels = kmeans.labels_
data_labeled = np.column_stack((projections, labels))
temp_df = pd.DataFrame(data_labeled, columns=['X', 'Y', 'labels'])
temp_df['labels'] = temp_df['labels'].astype('str')
# Out:
# /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning

# %%
build_scatter_2d(temp_df, projections, 'Description: K-means / UMAP')

# %%
df['detailed_cluster'] = labels

# %%
df.to_csv('.result_with_clusters.csv', index=False)
